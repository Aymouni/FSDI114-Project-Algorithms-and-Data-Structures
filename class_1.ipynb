# %% [markdown]
# # FSDI 114 - Data Structures and Algorithms
#
# ## Class 1
#
# #### This is an example of a text (paragraph from html)

# %%
for char in "Hello World":
    print(char)

# Press Shift + Enter
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
print("Hello World")
x = 10
print(x-5)
# Out:
# Hello World
# 5

# %%
print(x+10)
# Out:
# 20

# %% [markdown]
# ### Python Recap
#
#     - Lists
#     - Variables
#     - Expressions

# %%
# Variables
my_name = "John"
age = 25
is_active = True
print(f"My name is {my_name}")
# Out:
# My name is John

# %%
# Collections (Lists, Dictionaries, Tuples, Sets)
students = ["Leo", "Freysy", "charles", "Trishon"]
diff = ["String", 10, True, 'c']
my_dictionary = {
    "name":"Leo",
    "age":25,
    "is_active":True
}
print(students[1])
print(my_dictionary["name"])
# Out:
# Freysy
# Leo

# %%
# Expression - Operators
a = 10
b = 3

# Arithmetics
print(a + b)
print(a - b)
print(a * b)
print(a / b)

# Relational
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
print(a == b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# True
# False
# True
# False
# False

# %%
# Funstions
def my_function():
    a = 10
    b = 3
    print(a + b)

def my_function_with_parameters(a,b):
    print(a +b)

def my_function_with_return():
    a = 10
    b = 3
    return a+b

my_function()
my_function_with_parameters(10,3)
result = my_function_with_return()
print(result)
# Out:
# 13
# 13
# 13

# %% [markdown]
# Pseudocode Challenge 1: How to make a PB&J sandwich:
#
# START
#
# GATHER INGREDIENTS:
#     Get two slices of bread
#     Get peanut butter, jelly, and a knife
#     Place everything on a clean surface
#
# PREPARE THE BREAD:
#     Open the bread bag and take out two slices
#     Place them on a plate next to each other
#
# ADD PEANUT BUTTER:
#     Open the peanut butter jar
#     Use the knife to scoop some peanut butter
#     Spread it on one side of the first slice
#
# ADD JELLY:
#     Open the jelly jar
#     Use the knife to scoop some jelly
#     Spread it on one side of the second slice
#
# COMBINE THE SLICES:
#     Flip the jelly slice onto the peanut butter slice
#     Press them together lightly
#
# FINISH AND SERVE:
#     Cut the sandwich in half if desired
#     Place on a plate and serve
#
# END

# %% [markdown]
# Pseudocode Challenge 2: Largest number determination
#
# START
#
# I have a list of numbers: 12, 4, 27, 3, 188, 50, 7
#
# Go through each number in the list one by one
#     Keep track of the biggest number seen so far
#     If the current number is bigger, replace it
#
# When done, print the biggest number
#
# END

# %%
# Assignment 1: Second Problem:

nums = [12, 4, 27, 3, 1000, 50, 7]

largest = nums[0]

for num in nums:
    if num > largest:
        largest = num

print("The largest number is:", largest)
# Out:
# The largest number is: 1000

# %%
# Assignment 1: First Problem:

def count_even_numbers(collection):
    total = 0
    for number in collection:
        if number % 2 == 0:
            total += 1
    return total

numbers = [3, 5, 27, 20, 6, 3.5, 60]
print(count_even_numbers(numbers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 11
#       7             total += 1
#       8     return total
#       9
#      10 numbers = [3, 5, 27, 20, 6, 3.5, 60, "1", "2"]
# ---> 11 print(count_even_numbers(numbers))
#
# Cell In[23], line 6, in count_even_numbers(collection)
#       3 def count_even_numbers(collection):
#       4     total = 0
#       5     for number in collection:
# ----> 6         if number % 2 == 0:
#       7             total += 1
#       8     return total
#
# TypeError: not all arguments converted during string formatting
